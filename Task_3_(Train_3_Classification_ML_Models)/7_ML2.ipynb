# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel(r"D:\Projects\Data\Sleep_Work_Productivity_Surve.xlsx")

# clean age column
df['Enter your age ?']= df['Enter your age ?'].fillna(df['Enter your age ?'].median())

# rename the columns
df.rename(columns={
    'How would you rate your overall work productivity?': 'work_productivity',
    'How much do you think your sleep affects your productivity at work?': 'sleep_productivity_effect',
    'What factors do you believe impact your sleep quality? (Select all that apply)': 'sleep_factors',
    'How many breaks do you take during your workday when you are tired ?': 'break_nums',
    'How would you describe your energy levels throughout the workday?': 'energy_levels_per_workday',
    'What is your primary work environment?': 'primary_work_environment',
    'what is you gender ?': 'gender',
    'On a typical work night, how many hours of sleep do you get?': 'sleep_hours',
    
    'I wake up feeling refreshed and ready for work.':
        'wake_up_refreshed',

    'I have difficulty falling asleep the night before an important workday.':
        'difficulty_falling_asleep',

    'Enter your age ?':
        'age',

    'I wake up multiple times during the night and struggle to go back to sleep.':
        'wake_up_multiple_times',

    'On weekends or days off, my sleep schedule is very different from my workday schedule (e.g., sleeping in more than 2 hours later).':
        'weekend_sleep_schedule_difference',

    'I use electronic devices (phone, laptop, TV) in bed within 30 minutes of trying to sleep.':
        'device_use_before_sleep',

    'I find it hard to concentrate on work tasks for more than 15–20 minutes at a time.':
        'difficulty_concentrating',

    'I make careless mistakes (e.g., typos, miscalculations, forgetting steps) that I would not have made if better rested.':
        'careless_mistakes',

    'I often have to re-read emails, documents, or instructions because I lost focus.':
        'reread_due_to_focus_loss',

    'Learning a new software, process, or skill at work feels unusually difficult for me.':
        'difficulty_learning_new_skills',

    'I struggle to generate new ideas or creative solutions to problems.':
        'difficulty_generating_ideas',

    'I forget important tasks, deadlines, or details from meetings.':
        'forget_tasks_deadlines',

    'I feel irritable or short-tempered with colleagues or clients.':
        'irritable_with_colleagues',

    'Small setbacks or minor criticism feel overwhelming or upsetting.':
        'small_setbacks_overwhelming',

    'I avoid collaboration or group work because I feel mentally exhausted.':
        'avoid_collaboration',

    'I have difficulty controlling my emotions during stressful work situations (e.g., tight deadlines, difficult customers).':
        'difficulty_controlling_emotions',

    'I feel physically tired, sluggish, or heavy-eyed during work, even without heavy physical exertion.':
        'physically_tired_at_work',

    'In my job, I have had a close call, minor accident, or injury that I attribute to being too tired. If your job is sedentary, answer based on accidents like tripping, bumping into things, or spilling hot liquids.':
        'accident_due_to_tiredness',

    'Compared to when I am well-rested, I estimate my current work output is...':
        'current_work_output',

    'In the past month, how many work days did you feel you were “present but not productive” (getting less than half of your normal output) due to poor sleep?':
        'unproductive_workdays_due_to_sleep'

}, inplace=True)


# clean the names
df = df.replace(r'\n', ', ', regex=True)
df["sleep_factors"] = df["sleep_factors"].str.split(", ")


# Reverse the only positive-direction question
df['wake_up_refreshed_reverse'] = 6 - df['wake_up_refreshed']


# clean unproductive_workdays_due_to_sleep outlires
df.loc[df["unproductive_workdays_due_to_sleep"] > 23,
       "unproductive_workdays_due_to_sleep"] = np.nan

median = df['unproductive_workdays_due_to_sleep'].median().round(0)
df['unproductive_workdays_due_to_sleep'] = df['unproductive_workdays_due_to_sleep'].fillna(median)


# 1. Sleep Quality and Hygiene Index (SQLI)
# 5 questions × maximum score of 5 = 25
# Divide by 25 and multiply by 100 → maximum possible score = 100
df['sleep_quality_and_hygiene_index_(SQLI)'] = (
    (
        df['wake_up_refreshed_reverse']
        + df['difficulty_falling_asleep']
        + df['wake_up_multiple_times']
        + df['weekend_sleep_schedule_difference']
        + df['device_use_before_sleep']
    ) / 25
) * 100


# 2. Cognitive at-task Performance Index (CTPI)
# 6 questions × maximum score of 5 = 30
# Divide by 30 and multiply by 100 → maximum possible score = 100
df['Cognitive_at_task_perforamnce_index_(CTPI)'] = (
    (df['difficulty_concentrating']
     + df['careless_mistakes']
     + df['reread_due_to_focus_loss']
     + df['difficulty_learning_new_skills']
     + df['difficulty_generating_ideas']
     + df['forget_tasks_deadlines']) / 30
) * 100

df['Cognitive_at_task_perforamnce_index_(CTPI)'] = (
    df['Cognitive_at_task_perforamnce_index_(CTPI)'].round(2)
)


# 3. Emotional and Social Impact Index (ESII)
# 4 questions × maximum score of 5 = 20
# Divide by 20 and multiply by 100 → maximum possible score = 100
df['Emotional_and_social_impact_index(ESII)'] = (
    (df['irritable_with_colleagues']
     + df['small_setbacks_overwhelming']
     + df['avoid_collaboration']
     + df['difficulty_controlling_emotions']) / 20
) * 100


# 4. Physical and Safety Risk Index (PSRI)
# 2 questions × maximum score of 5 = 10
# Divide by 10 and multiply by 100 → maximum possible score = 100
df['Physical_and_safety_risk_index(PSRI)'] = (
    (df['physically_tired_at_work']
     + df['accident_due_to_tiredness']) / 10
) * 100


# 5. Presentative Index (PI)
output_loss_map = {
    'About the same or better': 0.00,
    '20–40% less': 0.30,
    '40–60% less': 0.50,
    '60–80% less': 0.70,
    '80–100% less':1.00
}

df['productivity_loss_fraction'] = (
    df['current_work_output'].map(output_loss_map)
)

df['Presentative_index(PI)'] = (
    (df['unproductive_workdays_due_to_sleep'] / 23)
    * df['productivity_loss_fraction']
    * 100
)

df['Presentative_index(PI)'] = (
    df['Presentative_index(PI)'].round(2)
)


# 6. Overall Sleep Productivity Impact Index (SPI)
# Each component has a maximum of 100.
# Therefore, their total maximum = 400.
# Dividing by 4 gives an average with a maximum of 100.
df['Overall_sleep_Productivity_Impact_index(SPI)'] = (
    df['Cognitive_at_task_perforamnce_index_(CTPI)']
    + df['Emotional_and_social_impact_index(ESII)']
    + df['Physical_and_safety_risk_index(PSRI)']
    + df['Presentative_index(PI)']
) / 4

# %% [markdown]
# ## **The Qs We Are Going To Answer, Using ML Models**
#
# ### ML 2 — SPI
# - Can we predict overall sleep-related productivity impact from workers' sleep, work, and demographic characteristics, and which - - - characteristics are the most important predictors?

# %% [markdown]
# #### --> first of all we should split our data into 3 parts:
# #### 1) df1 (the df what we wanna encode)
# #### 2) df2 (the df what we will extract variables from)
# #### 3) df3 (our lables)

# %%
df1 = df.loc[:, 'Submission Date':'sleep_hours']
df1['current_work_output']= df['current_work_output']
df1 = df1.drop(columns='sleep_factors')

# %%
df2 = df.loc[:,'wake_up_refreshed':].drop(columns=['Overall_sleep_Productivity_Impact_index(SPI)', 'sleep_quality_and_hygiene_index_(SQLI)', 'current_work_output'])

# %%
df3 = df[['Overall_sleep_Productivity_Impact_index(SPI)', 'sleep_quality_and_hygiene_index_(SQLI)']]

# %%
categorical_cols = [
    'work_productivity',
    'sleep_productivity_effect',
    'break_nums',
    'energy_levels_per_workday',
    'primary_work_environment',
    'gender',
    'sleep_hours',
    'current_work_output'
]

for col in categorical_cols:
    print("\n" + "="*50)
    print(col)
    print(df1[col].value_counts(dropna=False))
# Out:
# ==================================================
# work_productivity
# work_productivity
# Moderate     64
# High         35
# Low          16
# Very high    12
# Name: count, dtype: int64
#
# ==================================================
# sleep_productivity_effect
# sleep_productivity_effect
# Significantly    59
# Moderately       28
# Extremely        28
# A little          8
# Not at all        4
# Name: count, dtype: int64
#
# ==================================================
# break_nums
# break_nums
# 3-4          43
# 1-2          43
# 5 or more    36
# NaN           5
# Name: count, dtype: int64
#
# ==================================================
# energy_levels_per_workday
# energy_levels_per_workday
# Moderate     84
# High         24
# Low          14
# Very high     3
# Very low      2
# Name: count, dtype: int64
#
# ==================================================
# primary_work_environment
# primary_work_environment
# Hybrid        50
# Office        44
# Remote        25
# Field work     6
# NaN            2
# Name: count, dtype: int64
#
# ==================================================
# gender
# gender
# Female               79
# Male                 47
# Prefer not to say     1
# Name: count, dtype: int64
#
# ==================================================
# sleep_hours
# sleep_hours
# 6–7 hrs            34
# 5–6 hrs            33
# 7–8 hrs            33
# Less than 5 hrs    16
# More than 8 hrs    11
# Name: count, dtype: int64
#
# ==================================================
# current_work_output
# current_work_output
# 40–60% less                 33
# 20–40% less                 26
# 60–80% less                 25
# About the same or better    23
# 80–100% less                20
# Name: count, dtype: int64

# %%
#encode the variables of df1
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(
    handle_unknown='ignore',
    sparse_output=False
)

encoded = encoder.fit_transform(
    df1[['primary_work_environment', 'gender']]
)

encoded_df = pd.DataFrame(
    encoded,
    columns=encoder.get_feature_names_out(
        ['primary_work_environment', 'gender']
    ),
    index=df1.index
)

df1 = pd.concat([df1, encoded_df], axis=1)


work_productivity_map = {
    'Low': 0,
    'Moderate': 1,
    'High': 2,
    'Very high': 3
}

df1['work_productivity_encoded'] = (
    df1['work_productivity'].map(work_productivity_map)
)


sleep_effect_map = {
    'Not at all': 0,
    'A little': 1,
    'Moderately': 2,
    'Significantly': 3,
    'Extremely': 4
}

df1['sleep_productivity_effect_encoded'] = (
    df1['sleep_productivity_effect'].map(sleep_effect_map)
)


break_map = {
    '1-2': 1,
    '3-4': 2,
    '5 or more': 3
}

df1['break_nums_encoded'] = (
    df1['break_nums'].map(break_map)
)

break_nums_encoded_median = df1['break_nums_encoded'].median()
df1['break_nums_encoded'] = df1['break_nums_encoded'].fillna(break_nums_encoded_median)


energy_map = {
    'Very low': 0,
    'Low': 1,
    'Moderate': 2,
    'High': 3,
    'Very high': 4
}

df1['energy_encoded'] = (
    df1['energy_levels_per_workday'].map(energy_map)
)


sleep_hours_map = {
    'Less than 5 hrs': 0,
    '5–6 hrs': 1,
    '6–7 hrs': 2,
    '7–8 hrs': 3,
    'More than 8 hrs': 4
}

df1['sleep_hours_encoded'] = (
    df1['sleep_hours'].map(sleep_hours_map)
)

# %%
df1_encoded = df1.iloc[:, 9:]
df3_SPI = df3['Overall_sleep_Productivity_Impact_index(SPI)']

# %%
df_SPI = pd.concat([df1_encoded, df2, df3_SPI], axis=1)

# %%
df_SPI.drop(columns=[
    'Cognitive_at_task_perforamnce_index_(CTPI)',
    'Emotional_and_social_impact_index(ESII)',
    'Physical_and_safety_risk_index(PSRI)',
    'Presentative_index(PI)',
    'wake_up_refreshed'
]).corr()
# Out:
#                                               primary_work_environment_Field work  \
# primary_work_environment_Field work                                      1.000000
# primary_work_environment_Hybrid                                         -0.179441
# primary_work_environment_Office                                         -0.162133
# primary_work_environment_Remote                                         -0.110243
# primary_work_environment_nan                                            -0.028167
# gender_Female                                                           -0.132593
# gender_Male                                                              0.136787
# gender_Prefer not to say                                                -0.019838
# work_productivity_encoded                                               -0.046949
# sleep_productivity_effect_encoded                                       -0.064623
# break_nums_encoded                                                       0.015600
# energy_encoded                                                          -0.031444
# sleep_hours_encoded                                                     -0.016765
# difficulty_falling_asleep                                                0.059245
# age                                                                      0.006232
# wake_up_multiple_times                                                  -0.056755
# weekend_sleep_schedule_difference                                       -0.066439
# device_use_before_sleep                                                 -0.072634
# difficulty_concentrating                                                 0.061459
# careless_mistakes                                                        0.014045
# reread_due_to_focus_loss                                                -0.042201
# difficulty_learning_new_skills                                          -0.126475
# difficulty_generating_ideas                                              0.028654
# forget_tasks_deadlines                                                   0.009188
# irritable_with_colleagues                                               -0.026738
# small_setbacks_overwhelming                                             -0.086834
# avoid_collaboration                                                     -0.062134
# difficulty_controlling_emotions                                          0.045403
# physically_tired_at_work                                                -0.069687
# accident_due_to_tiredness                                                0.039897
# unproductive_workdays_due_to_sleep                                       0.101163
# wake_up_refreshed_reverse                                                0.059523
# productivity_loss_fraction                                               0.091339
# Overall_sleep_Productivity_Impact_index(SPI)                             0.013684
#
#                                               primary_work_environment_Hybrid  \
# primary_work_environment_Field work                                 -0.179441
# primary_work_environment_Hybrid                                      1.000000
# primary_work_environment_Office                                     -0.586715
# primary_work_environment_Remote                                     -0.398942
# primary_work_environment_nan                                        -0.101929
# gender_Female                                                        0.029836
# gender_Male                                                         -0.050201
# gender_Prefer not to say                                             0.110554
# work_productivity_encoded                                           -0.018364
# sleep_productivity_effect_encoded                                   -0.016337
# break_nums_encoded                                                   0.097421
# energy_encoded                                                       0.006638
# sleep_hours_encoded                                                  0.040531
# difficulty_falling_asleep                                            0.013766
# age                                                                 -0.217590
# wake_up_multiple_times                                              -0.050967
# weekend_sleep_schedule_difference                                    0.091087
# device_use_before_sleep                                              0.090864
# difficulty_concentrating                                             0.181069
# careless_mistakes                                                    0.110761
# reread_due_to_focus_loss                                            -0.143077
# difficulty_learning_new_skills                                       0.083943
# difficulty_generating_ideas                                         -0.042106
# forget_tasks_deadlines                                              -0.031714
# irritable_with_colleagues                                            0.182094
# small_setbacks_overwhelming                                          0.106877
# avoid_collaboration                                                  0.047323
# difficulty_controlling_emotions                                      0.090521
# physically_tired_at_work                                             0.173234
# accident_due_to_tiredness                                            0.053888
# unproductive_workdays_due_to_sleep                                   0.014795
# wake_up_refreshed_reverse                                            0.170274
# productivity_loss_fraction                                          -0.082889
# Overall_sleep_Productivity_Impact_index(SPI)                         0.081390
#
#                                               primary_work_environment_Office  \
# primary_work_environment_Field work                                 -0.162133
# primary_work_environment_Hybrid                                     -0.586715
# primary_work_environment_Office                                      1.000000
# primary_work_environment_Remote                                     -0.360460
# primary_work_environment_nan                                        -0.092097
# gender_Female                                                       -0.012630
# gender_Male                                                          0.024557
# gender_Prefer not to say                                            -0.064864
# work_productivity_encoded                                            0.245601
# sleep_productivity_effect_encoded                                   -0.005140
# break_nums_encoded                                                  -0.054154
# energy_encoded                                                       0.070293
# sleep_hours_encoded                                                  0.077429
# difficulty_falling_asleep                                           -0.056422
# age                                                                  0.394499
# wake_up_multiple_times                                               0.024394
# weekend_sleep_schedule_difference                                   -0.091831
# device_use_before_sleep                                             -0.078603
# difficulty_concentrating                                            -0.336626
# careless_mistakes                                                   -0.247577
# reread_due_to_focus_loss                                            -0.053877
# difficulty_learning_new_skills                                      -0.074440
# difficulty_generating_ideas                                         -0.012548
# forget_tasks_deadlines                                              -0.170058
# irritable_with_colleagues                                           -0.281537
# small_setbacks_overwhelming                                         -0.092872
# avoid_collaboration                                                 -0.171090
# difficulty_controlling_emotions                                     -0.097751
# physically_tired_at_work                                            -0.237782
# accident_due_to_tiredness                                           -0.079818
# unproductive_workdays_due_to_sleep                                  -0.116121
# wake_up_refreshed_reverse                                           -0.233926
# productivity_loss_fraction                                           0.114243
# Overall_sleep_Productivity_Impact_index(SPI)                        -0.203032
#
#                                               primary_work_environment_Remote  \
# primary_work_environment_Field work                                 -0.110243
# primary_work_environment_Hybrid                                     -0.398942
# primary_work_environment_Office                                     -0.360460
# primary_work_environment_Remote                                      1.000000
# primary_work_environment_nan                                        -0.062622
# gender_Female                                                        0.018330
# gender_Male                                                         -0.010334
# gender_Prefer not to say                                            -0.044105
# work_productivity_encoded                                           -0.229856
# sleep_productivity_effect_encoded                                    0.051641
# break_nums_encoded                                                  -0.065997
# energy_encoded                                                      -0.099501
# sleep_hours_encoded                                                 -0.102274
# difficulty_falling_asleep                                           -0.009151
# age                                                                 -0.185113
# wake_up_multiple_times                                               0.022531
# weekend_sleep_schedule_difference                                    0.039882
# device_use_before_sleep                                              0.055824
# difficulty_concentrating                                             0.136638
# careless_mistakes                                                    0.161523
# reread_due_to_focus_loss                                             0.293986
# difficulty_learning_new_skills                                       0.092152
# difficulty_generating_ideas                                          0.104157
# forget_tasks_deadlines                                               0.219981
# irritable_with_colleagues                                            0.138007
# small_setbacks_overwhelming                                          0.065662
# avoid_collaboration                                                  0.152428
# difficulty_controlling_emotions                                      0.030115
# physically_tired_at_work                                             0.133160
# accident_due_to_tiredness                                            0.024329
# unproductive_workdays_due_to_sleep                                   0.092690
# wake_up_refreshed_reverse                                            0.021446
# productivity_loss_fraction                                          -0.116505
# Overall_sleep_Productivity_Impact_index(SPI)                         0.164366
#
#                                               primary_work_environment_nan  \
# primary_work_environment_Field work                              -0.028167
# primary_work_environment_Hybrid                                  -0.101929
# primary_work_environment_Office                                  -0.092097
# primary_work_environment_Remote                                  -0.062622
# primary_work_environment_nan                                      1.000000
# gender_Female                                                     0.098598
# gender_Male                                                      -0.096954
# gender_Prefer not to say                                         -0.011269
# work_productivity_encoded                                        -0.052523
# sleep_productivity_effect_encoded                                 0.028953
# break_nums_encoded                                                0.008861
# energy_encoded                                                    0.076655
# sleep_hours_encoded                                              -0.099782
# difficulty_falling_asleep                                         0.089890
# age                                                              -0.073325
# wake_up_multiple_times                                            0.131535
# weekend_sleep_schedule_difference                                -0.020622
# device_use_before_sleep                                          -0.110661
# difficulty_concentrating                                          0.034911
# careless_mistakes                                                -0.028208
# reread_due_to_focus_loss                                         -0.099609
# difficulty_learning_new_skills                                   -0.123684
# difficulty_generating_ideas                                      -0.168288
# forget_tasks_deadlines                                            0.056205
# irritable_with_colleagues                                        -0.033736
# small_setbacks_overwhelming                                      -0.126188
# avoid_collaboration                                               0.087271
# difficulty_controlling_emotions                                  -0.155172
# physically_tired_at_work                                         -0.077527
# accident_due_to_tiredness                                        -0.052096
# unproductive_workdays_due_to_sleep                               -0.082663
# wake_up_refreshed_reverse                                         0.055945
# productivity_loss_fraction                                        0.105077
# Overall_sleep_Productivity_Impact_index(SPI)                     -0.091660
#
#                                               gender_Female  gender_Male  \
# primary_work_environment_Field work               -0.132593     0.136787
# primary_work_environment_Hybrid                    0.029836    -0.050201
# primary_work_environment_Office                   -0.012630     0.024557
# primary_work_environment_Remote                    0.018330    -0.010334
# primary_work_environment_nan                       0.098598    -0.096954
# gender_Female                                      1.000000    -0.983325
# gender_Male                                       -0.983325     1.000000
# gender_Prefer not to say                          -0.114290    -0.068284
# work_productivity_encoded                         -0.094559     0.061732
# sleep_productivity_effect_encoded                  0.023895    -0.027730
# break_nums_encoded                                 0.089875    -0.070671
# energy_encoded                                    -0.253958     0.257339
# sleep_hours_encoded                               -0.108176     0.121500
# difficulty_falling_asleep                          0.168045    -0.173097
# age                                               -0.282174     0.251285
# wake_up_multiple_times                             0.072514    -0.064442
# weekend_sleep_schedule_difference                  0.113896    -0.091858
# device_use_before_sleep                            0.147332    -0.147112
# difficulty_concentrating                           0.076412    -0.081237
# careless_mistakes                                  0.187765    -0.198921
# reread_due_to_focus_loss                           0.249683    -0.230587
# difficulty_learning_new_skills                     0.243056    -0.234826
# difficulty_generating_ideas                        0.212470    -0.205953
# forget_tasks_deadlines                             0.111844    -0.106418
# irritable_with_colleagues                          0.193606    -0.182905
# small_setbacks_overwhelming                        0.244753    -0.244388
# avoid_collaboration                                0.042161    -0.033275
# difficulty_controlling_emotions                    0.147737    -0.149356
# physically_tired_at_work                           0.390070    -0.389069
# accident_due_to_tiredness                          0.076291    -0.069898
# unproductive_workdays_due_to_sleep                 0.276015    -0.257741
# wake_up_refreshed_reverse                          0.251987    -0.251709
# productivity_loss_fraction                        -0.207048     0.181521
# Overall_sleep_Productivity_Impact_index(SPI)       0.308767    -0.299398
#
#                                               gender_Prefer not to say  \
# primary_work_environment_Field work                          -0.019838
# primary_work_environment_Hybrid                               0.110554
# primary_work_environment_Office                              -0.064864
# primary_work_environment_Remote                              -0.044105
# primary_work_environment_nan                                 -0.011269
# gender_Female                                                -0.114290
# gender_Male                                                  -0.068284
# gender_Prefer not to say                                      1.000000
# work_productivity_encoded                                     0.181518
# sleep_productivity_effect_encoded                             0.020391
# break_nums_encoded                                           -0.106990
# energy_encoded                                               -0.012580
# sleep_hours_encoded                                          -0.070276
# difficulty_falling_asleep                                     0.023702
# age                                                           0.175283
# wake_up_multiple_times                                       -0.045775
# weekend_sleep_schedule_difference                            -0.123028
# device_use_before_sleep                                      -0.004619
# difficulty_concentrating                                      0.024588
# careless_mistakes                                             0.056590
# reread_due_to_focus_loss                                     -0.110108
# difficulty_learning_new_skills                               -0.050598
# difficulty_generating_ideas                                  -0.040532
# forget_tasks_deadlines                                       -0.032233
# irritable_with_colleagues                                    -0.062949
# small_setbacks_overwhelming                                  -0.007673
# avoid_collaboration                                          -0.049521
# difficulty_controlling_emotions                               0.005419
# physically_tired_at_work                                     -0.014518
# accident_due_to_tiredness                                    -0.036691
# unproductive_workdays_due_to_sleep                           -0.106231
# wake_up_refreshed_reverse                                    -0.007365
# productivity_loss_fraction                                    0.144249
# Overall_sleep_Productivity_Impact_index(SPI)                 -0.058346
#
#                                               work_productivity_encoded  \
# primary_work_environment_Field work                           -0.046949
# primary_work_environment_Hybrid                               -0.018364
# primary_work_environment_Office                                0.245601
# primary_work_environment_Remote                               -0.229856
# primary_work_environment_nan                                  -0.052523
# gender_Female                                                 -0.094559
# gender_Male                                                    0.061732
# gender_Prefer not to say                                       0.181518
# work_productivity_encoded                                      1.000000
# sleep_productivity_effect_encoded                             -0.005210
# break_nums_encoded                                            -0.265478
# energy_encoded                                                 0.432021
# sleep_hours_encoded                                           -0.071227
# difficulty_falling_asleep                                     -0.001149
# age                                                            0.419570
# wake_up_multiple_times                                         0.094214
# weekend_sleep_schedule_difference                             -0.204911
# device_use_before_sleep                                       -0.013579
# difficulty_concentrating                                      -0.397239
# careless_mistakes                                             -0.183760
# reread_due_to_focus_loss                                      -0.166750
# difficulty_learning_new_skills                                -0.227922
# difficulty_generating_ideas                                   -0.298818
# forget_tasks_deadlines                                        -0.189162
# irritable_with_colleagues                                     -0.276410
# small_setbacks_overwhelming                                   -0.150184
# avoid_collaboration                                           -0.030313
# difficulty_controlling_emotions                               -0.148810
# physically_tired_at_work                                      -0.354428
# accident_due_to_tiredness                                     -0.051163
# unproductive_workdays_due_to_sleep                            -0.247070
# wake_up_refreshed_reverse                                     -0.439867
# productivity_loss_fraction                                     0.060169
# Overall_sleep_Productivity_Impact_index(SPI)                  -0.339533
#
#                                               sleep_productivity_effect_encoded  \
# primary_work_environment_Field work                                   -0.064623
# primary_work_environment_Hybrid                                       -0.016337
# primary_work_environment_Office                                       -0.005140
# primary_work_environment_Remote                                        0.051641
# primary_work_environment_nan                                           0.028953
# gender_Female                                                          0.023895
# gender_Male                                                           -0.027730
# gender_Prefer not to say                                               0.020391
# work_productivity_encoded                                             -0.005210
# sleep_productivity_effect_encoded                                      1.000000
# break_nums_encoded                                                     0.067087
# energy_encoded                                                        -0.065412
# sleep_hours_encoded                                                    0.047566
# difficulty_falling_asleep                                              0.040866
# age                                                                   -0.037981
# wake_up_multiple_times                                                -0.117361
# weekend_sleep_schedule_difference                                      0.123607
# device_use_before_sleep                                                0.085874
# difficulty_concentrating                                               0.167454
# careless_mistakes                                                      0.198376
# reread_due_to_focus_loss                                               0.114258
# difficulty_learning_new_skills                                        -0.004010
# difficulty_generating_ideas                                            0.111296
# forget_tasks_deadlines                                                -0.062166
# irritable_with_colleagues                                              0.104200
# small_setbacks_overwhelming                                            0.079322
# avoid_collaboration                                                    0.011815
# difficulty_controlling_emotions                                        0.014145
# physically_tired_at_work                                               0.022590
# accident_due_to_tiredness                                             -0.130392
# unproductive_workdays_due_to_sleep                                     0.206857
# wake_up_refreshed_reverse                                              0.001757
# productivity_loss_fraction                                             0.194020
# Overall_sleep_Productivity_Impact_index(SPI)                           0.124037
#
#                                               ...  irritable_with_colleagues  \
# primary_work_environment_Field work           ...                  -0.026738
# primary_work_environment_Hybrid               ...                   0.182094
# primary_work_environment_Office               ...                  -0.281537
# primary_work_environment_Remote               ...                   0.138007
# primary_work_environment_nan                  ...                  -0.033736
# gender_Female                                 ...                   0.193606
# gender_Male                                   ...                  -0.182905
# gender_Prefer not to say                      ...                  -0.062949
# work_productivity_encoded                     ...                  -0.276410
# sleep_productivity_effect_encoded             ...                   0.104200
# break_nums_encoded                            ...                   0.075916
# energy_encoded                                ...                  -0.141186
# sleep_hours_encoded                           ...                  -0.248947
# difficulty_falling_asleep                     ...                   0.089437
# age                                           ...                  -0.333486
# wake_up_multiple_times                        ...                  -0.024026
# weekend_sleep_schedule_difference             ...                   0.109796
# device_use_before_sleep                       ...                   0.168616
# difficulty_concentrating                      ...                   0.242397
# careless_mistakes                             ...                   0.270488
# reread_due_to_focus_loss                      ...                   0.245117
# difficulty_learning_new_skills                ...                   0.052938
# difficulty_generating_ideas                   ...                   0.145506
# forget_tasks_deadlines                        ...                   0.252538
# irritable_with_colleagues                     ...                   1.000000
# small_setbacks_overwhelming                   ...                   0.425338
# avoid_collaboration                           ...                   0.366686
# difficulty_controlling_emotions               ...                   0.405712
# physically_tired_at_work                      ...                   0.539395
# accident_due_to_tiredness                     ...                   0.188013
# unproductive_workdays_due_to_sleep            ...                   0.192824
# wake_up_refreshed_reverse                     ...                   0.159781
# productivity_loss_fraction                    ...                  -0.096891
# Overall_sleep_Productivity_Impact_index(SPI)  ...                   0.571091
#
#                                               small_setbacks_overwhelming  \
# primary_work_environment_Field work                             -0.086834
# primary_work_environment_Hybrid                                  0.106877
# primary_work_environment_Office                                 -0.092872
# primary_work_environment_Remote                                  0.065662
# primary_work_environment_nan                                    -0.126188
# gender_Female                                                    0.244753
# gender_Male                                                     -0.244388
# gender_Prefer not to say                                        -0.007673
# work_productivity_encoded                                       -0.150184
# sleep_productivity_effect_encoded                                0.079322
# break_nums_encoded                                               0.097254
# energy_encoded                                                  -0.108691
# sleep_hours_encoded                                             -0.043357
# difficulty_falling_asleep                                       -0.060048
# age                                                             -0.250304
# wake_up_multiple_times                                          -0.122308
# weekend_sleep_schedule_difference                                0.143302
# device_use_before_sleep                                          0.125483
# difficulty_concentrating                                         0.128077
# careless_mistakes                                                0.319565
# reread_due_to_focus_loss                                         0.350610
# difficulty_learning_new_skills                                   0.268757
# difficulty_generating_ideas                                      0.174446
# forget_tasks_deadlines                                           0.136627
# irritable_with_colleagues                                        0.425338
# small_setbacks_overwhelming                                      1.000000
# avoid_collaboration                                              0.285931
# difficulty_controlling_emotions                                  0.424160
# physically_tired_at_work                                         0.360550
# accident_due_to_tiredness                                        0.180859
# unproductive_workdays_due_to_sleep                               0.044283
# wake_up_refreshed_reverse                                        0.181260
# productivity_loss_fraction                                      -0.009945
# Overall_sleep_Productivity_Impact_index(SPI)                     0.513312
#
#                                               avoid_collaboration  \
# primary_work_environment_Field work                     -0.062134
# primary_work_environment_Hybrid                          0.047323
# primary_work_environment_Office                         -0.171090
# primary_work_environment_Remote                          0.152428
# primary_work_environment_nan                             0.087271
# gender_Female                                            0.042161
# gender_Male                                             -0.033275
# gender_Prefer not to say                                -0.049521
# work_productivity_encoded                               -0.030313
# sleep_productivity_effect_encoded                        0.011815
# break_nums_encoded                                      -0.052491
# energy_encoded                                           0.048558
# sleep_hours_encoded                                     -0.214511
# difficulty_falling_asleep                               -0.148671
# age                                                     -0.151732
# wake_up_multiple_times                                   0.049684
# weekend_sleep_schedule_difference                        0.081950
# device_use_before_sleep                                 -0.007289
# difficulty_concentrating                                 0.008056
# careless_mistakes                                        0.173503
# reread_due_to_focus_loss                                 0.198698
# difficulty_learning_new_skills                           0.118479
# difficulty_generating_ideas                              0.124965
# forget_tasks_deadlines                                   0.299718
# irritable_with_colleagues                                0.366686
# small_setbacks_overwhelming                              0.285931
# avoid_collaboration                                      1.000000
# difficulty_controlling_emotions                          0.219062
# physically_tired_at_work                                 0.209540
# accident_due_to_tiredness                                0.113123
# unproductive_workdays_due_to_sleep                       0.104309
# wake_up_refreshed_reverse                               -0.025356
# productivity_loss_fraction                               0.068845
# Overall_sleep_Productivity_Impact_index(SPI)             0.445637
#
#                                               difficulty_controlling_emotions  \
# primary_work_environment_Field work                                  0.045403
# primary_work_environment_Hybrid                                      0.090521
# primary_work_environment_Office                                     -0.097751
# primary_work_environment_Remote                                      0.030115
# primary_work_environment_nan                                        -0.155172
# gender_Female                                                        0.147737
# gender_Male                                                         -0.149356
# gender_Prefer not to say                                             0.005419
# work_productivity_encoded                                           -0.148810
# sleep_productivity_effect_encoded                                    0.014145
# break_nums_encoded                                                   0.116008
# energy_encoded                                                      -0.112619
# sleep_hours_encoded                                                 -0.027251
# difficulty_falling_asleep                                            0.055934
# age                                                                 -0.127113
# wake_up_multiple_times                                               0.078512
# weekend_sleep_schedule_difference                                    0.078518
# device_use_before_sleep                                              0.208972
# difficulty_concentrating                                             0.145003
# careless_mistakes                                                    0.181785
# reread_due_to_focus_loss                                             0.269181
# difficulty_learning_new_skills                                       0.211834
# difficulty_generating_ideas                                          0.252530
# forget_tasks_deadlines                                               0.294447
# irritable_with_colleagues                                            0.405712
# small_setbacks_overwhelming                                          0.424160
# avoid_collaboration                                                  0.219062
# difficulty_controlling_emotions                                      1.000000
# physically_tired_at_work                                             0.399172
# accident_due_to_tiredness                                            0.264733
# unproductive_workdays_due_to_sleep                                   0.038539
# wake_up_refreshed_reverse                                            0.146954
# productivity_loss_fraction                                          -0.138998
# Overall_sleep_Productivity_Impact_index(SPI)                         0.488541
#
#                                               physically_tired_at_work  \
# primary_work_environment_Field work                          -0.069687
# primary_work_environment_Hybrid                               0.173234
# primary_work_environment_Office                              -0.237782
# primary_work_environment_Remote                               0.133160
# primary_work_environment_nan                                 -0.077527
# gender_Female                                                 0.390070
# gender_Male                                                  -0.389069
# gender_Prefer not to say                                     -0.014518
# work_productivity_encoded                                    -0.354428
# sleep_productivity_effect_encoded                             0.022590
# break_nums_encoded                                            0.146506
# energy_encoded                                               -0.298324
# sleep_hours_encoded                                          -0.152827
# difficulty_falling_asleep                                     0.100062
# age                                                          -0.344322
# wake_up_multiple_times                                        0.202494
# weekend_sleep_schedule_difference                             0.309999
# device_use_before_sleep                                       0.195655
# difficulty_concentrating                                      0.263052
# careless_mistakes                                             0.292034
# reread_due_to_focus_loss                                      0.326079
# difficulty_learning_new_skills                                0.215259
# difficulty_generating_ideas                                   0.223609
# forget_tasks_deadlines                                        0.312323
# irritable_with_colleagues                                     0.539395
# small_setbacks_overwhelming                                   0.360550
# avoid_collaboration                                           0.209540
# difficulty_controlling_emotions                               0.399172
# physically_tired_at_work                                      1.000000
# accident_due_to_tiredness                                     0.309777
# unproductive_workdays_due_to_sleep                            0.303367
# wake_up_refreshed_reverse                                     0.284097
# productivity_loss_fraction                                   -0.165196
# Overall_sleep_Productivity_Impact_index(SPI)                  0.693077
#
#                                               accident_due_to_tiredness  \
# primary_work_environment_Field work                            0.039897
# primary_work_environment_Hybrid                                0.053888
# primary_work_environment_Office                               -0.079818
# primary_work_environment_Remote                                0.024329
# primary_work_environment_nan                                  -0.052096
# gender_Female                                                  0.076291
# gender_Male                                                   -0.069898
# gender_Prefer not to say                                      -0.036691
# work_productivity_encoded                                     -0.051163
# sleep_productivity_effect_encoded                             -0.130392
# break_nums_encoded                                             0.099832
# energy_encoded                                                -0.131180
# sleep_hours_encoded                                            0.069609
# difficulty_falling_asleep                                      0.016470
# age                                                           -0.179126
# wake_up_multiple_times                                         0.254745
# weekend_sleep_schedule_difference                              0.128400
# device_use_before_sleep                                        0.070569
# difficulty_concentrating                                       0.197218
# careless_mistakes                                              0.135809
# reread_due_to_focus_loss                                       0.117090
# difficulty_learning_new_skills                                 0.189496
# difficulty_generating_ideas                                    0.154850
# forget_tasks_deadlines                                         0.295551
# irritable_with_colleagues                                      0.188013
# small_setbacks_overwhelming                                    0.180859
# avoid_collaboration                                            0.113123
# difficulty_controlling_emotions                                0.264733
# physically_tired_at_work                                       0.309777
# accident_due_to_tiredness                                      1.000000
# unproductive_workdays_due_to_sleep                            -0.023362
# wake_up_refreshed_reverse                                     -0.063364
# productivity_loss_fraction                                    -0.092694
# Overall_sleep_Productivity_Impact_index(SPI)                   0.487949
#
#                                               unproductive_workdays_due_to_sleep  \
# primary_work_environment_Field work                                     0.101163
# primary_work_environment_Hybrid                                         0.014795
# primary_work_environment_Office                                        -0.116121
# primary_work_environment_Remote                                         0.092690
# primary_work_environment_nan                                           -0.082663
# gender_Female                                                           0.276015
# gender_Male                                                            -0.257741
# gender_Prefer not to say                                               -0.106231
# work_productivity_encoded                                              -0.247070
# sleep_productivity_effect_encoded                                       0.206857
# break_nums_encoded                                                      0.205793
# energy_encoded                                                         -0.316351
# sleep_hours_encoded                                                     0.035583
# difficulty_falling_asleep                                               0.172609
# age                                                                    -0.413022
# wake_up_multiple_times                                                 -0.048982
# weekend_sleep_schedule_difference                                       0.088709
# device_use_before_sleep                                                 0.104655
# difficulty_concentrating                                                0.190039
# careless_mistakes                                                       0.313147
# reread_due_to_focus_loss                                                0.170502
# difficulty_learning_new_skills                                          0.270005
# difficulty_generating_ideas                                             0.210404
# forget_tasks_deadlines                                                  0.144417
# irritable_with_colleagues                                               0.192824
# small_setbacks_overwhelming                                             0.044283
# avoid_collaboration                                                     0.104309
# difficulty_controlling_emotions                                         0.038539
# physically_tired_at_work                                                0.303367
# accident_due_to_tiredness                                              -0.023362
# unproductive_workdays_due_to_sleep                                      1.000000
# wake_up_refreshed_reverse                                               0.283095
# productivity_loss_fraction                                              0.032051
# Overall_sleep_Productivity_Impact_index(SPI)                            0.508909
#
#                                               wake_up_refreshed_reverse  \
# primary_work_environment_Field work                            0.059523
# primary_work_environment_Hybrid                                0.170274
# primary_work_environment_Office                               -0.233926
# primary_work_environment_Remote                                0.021446
# primary_work_environment_nan                                   0.055945
# gender_Female                                                  0.251987
# gender_Male                                                   -0.251709
# gender_Prefer not to say                                      -0.007365
# work_productivity_encoded                                     -0.439867
# sleep_productivity_effect_encoded                              0.001757
# break_nums_encoded                                             0.226449
# energy_encoded                                                -0.320535
# sleep_hours_encoded                                           -0.157239
# difficulty_falling_asleep                                     -0.073566
# age                                                           -0.288645
# wake_up_multiple_times                                         0.021745
# weekend_sleep_schedule_difference                              0.134198
# device_use_before_sleep                                        0.104576
# difficulty_concentrating                                       0.220709
# careless_mistakes                                              0.080894
# reread_due_to_focus_loss                                       0.046125
# difficulty_learning_new_skills                                 0.047914
# difficulty_generating_ideas                                    0.042000
# forget_tasks_deadlines                                        -0.029912
# irritable_with_colleagues                                      0.159781
# small_setbacks_overwhelming                                    0.181260
# avoid_collaboration                                           -0.025356
# difficulty_controlling_emotions                                0.146954
# physically_tired_at_work                                       0.284097
# accident_due_to_tiredness                                     -0.063364
# unproductive_workdays_due_to_sleep                             0.283095
# wake_up_refreshed_reverse                                      1.000000
# productivity_loss_fraction                                    -0.061694
# Overall_sleep_Productivity_Impact_index(SPI)                   0.178904
#
#                                               productivity_loss_fraction  \
# primary_work_environment_Field work                             0.091339
# primary_work_environment_Hybrid                                -0.082889
# primary_work_environment_Office                                 0.114243
# primary_work_environment_Remote                                -0.116505
# primary_work_environment_nan                                    0.105077
# gender_Female                                                  -0.207048
# gender_Male                                                     0.181521
# gender_Prefer not to say                                        0.144249
# work_productivity_encoded                                       0.060169
# sleep_productivity_effect_encoded                               0.194020
# break_nums_encoded                                             -0.088182
# energy_encoded                                                  0.002250
# sleep_hours_encoded                                             0.020545
# difficulty_falling_asleep                                       0.015266
# age                                                             0.086615
# wake_up_multiple_times                                          0.069924
# weekend_sleep_schedule_difference                               0.052253
# device_use_before_sleep                                        -0.083654
# difficulty_concentrating                                       -0.026514
# careless_mistakes                                               0.013677
# reread_due_to_focus_loss                                       -0.068105
# difficulty_learning_new_skills                                  0.095225
# difficulty_generating_ideas                                     0.127915
# forget_tasks_deadlines                                         -0.036777
# irritable_with_colleagues                                      -0.096891
# small_setbacks_overwhelming                                    -0.009945
# avoid_collaboration                                             0.068845
# difficulty_controlling_emotions                                -0.138998
# physically_tired_at_work                                       -0.165196
# accident_due_to_tiredness                                      -0.092694
# unproductive_workdays_due_to_sleep                              0.032051
# wake_up_refreshed_reverse                                      -0.061694
# productivity_loss_fraction                                      1.000000
# Overall_sleep_Productivity_Impact_index(SPI)                    0.166131
#
#                                               Overall_sleep_Productivity_Impact_index(SPI)
# primary_work_environment_Field work                                               0.013684
# primary_work_environment_Hybrid                                                   0.081390
# primary_work_environment_Office                                                  -0.203032
# primary_work_environment_Remote                                                   0.164366
# primary_work_environment_nan                                                     -0.091660
# gender_Female                                                                     0.308767
# gender_Male                                                                      -0.299398
# gender_Prefer not to say                                                         -0.058346
# work_productivity_encoded                                                        -0.339533
# sleep_productivity_effect_encoded                                                 0.124037
# break_nums_encoded                                                                0.189446
# energy_encoded                                                                   -0.294931
# sleep_hours_encoded                                                              -0.061575
# difficulty_falling_asleep                                                         0.098383
# age                                                                              -0.473449
# wake_up_multiple_times                                                            0.154100
# weekend_sleep_schedule_difference                                                 0.251564
# device_use_before_sleep                                                           0.158060
# difficulty_concentrating                                                          0.462433
# careless_mistakes                                                                 0.554794
# reread_due_to_focus_loss                                                          0.467164
# difficulty_learning_new_skills                                                    0.512104
# difficulty_generating_ideas                                                       0.512151
# forget_tasks_deadlines                                                            0.521789
# irritable_with_colleagues                                                         0.571091
# small_setbacks_overwhelming                                                       0.513312
# avoid_collaboration                                                               0.445637
# difficulty_controlling_emotions                                                   0.488541
# physically_tired_at_work                                                          0.693077
# accident_due_to_tiredness                                                         0.487949
# unproductive_workdays_due_to_sleep                                                0.508909
# wake_up_refreshed_reverse                                                         0.178904
# productivity_loss_fraction                                                        0.166131
# Overall_sleep_Productivity_Impact_index(SPI)                                      1.000000
#
# [34 rows x 34 columns]

# %%
X2 = df_SPI.drop(columns=[
    'Overall_sleep_Productivity_Impact_index(SPI)',
    'Cognitive_at_task_perforamnce_index_(CTPI)',
    'Emotional_and_social_impact_index(ESII)',
    'Physical_and_safety_risk_index(PSRI)',
    'Presentative_index(PI)',
    'wake_up_refreshed'
])

y2 = df_SPI['Overall_sleep_Productivity_Impact_index(SPI)']

# %%
from sklearn.model_selection import train_test_split

# ML2 splitted
X2_train, X2_test, y2_train, y2_test = train_test_split(
    X2,
    y2,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor

# %%
R_model = Pipeline([
    ("scaler", StandardScaler()),
    ("model", Ridge(
        alpha=1.0
    ))
])


rf = RandomForestRegressor(
    n_estimators=300,
    random_state=42
)


gb = GradientBoostingRegressor(
    random_state=42
)

# %% [markdown]
# # **ML2 for SPI**

# %%
R_model.fit(X2_train, y2_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', Ridge())])

# %%
rf.fit(X2_train, y2_train)
# Out:
# RandomForestRegressor(n_estimators=300, random_state=42)

# %%
gb.fit(X2_train, y2_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y2_pred_ridge = R_model.predict(X2_test)
y2_pred_rf = rf.predict(X2_test)
y2_pred_gb = gb.predict(X2_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

ridge_mae = mean_absolute_error(y2_test, y2_pred_ridge)
ridge_rmse = np.sqrt(mean_squared_error(y2_test, y2_pred_ridge))
ridge_r2 = r2_score(y2_test, y2_pred_ridge)

# %%
rf_mae = mean_absolute_error(y2_test, y2_pred_rf)
rf_rmse = np.sqrt(mean_squared_error(y2_test, y2_pred_rf))
rf_r2 = r2_score(y2_test, y2_pred_rf)

# %%
gb_mae = mean_absolute_error(y2_test, y2_pred_gb)
gb_rmse = np.sqrt(mean_squared_error(y2_test, y2_pred_gb))
gb_r2 = r2_score(y2_test, y2_pred_gb)

# %%
results_spi = pd.DataFrame({
    "Model": ["Ridge", "Random Forest", "Gradient Boosting"],
    "MAE": [ridge_mae, rf_mae, gb_mae],
    "RMSE": [ridge_rmse, rf_rmse, gb_rmse],
    "R²": [ridge_r2, rf_r2, gb_r2]
})

results_spi.round(3)
# Out:
#                Model    MAE   RMSE     R²
# 0              Ridge  1.916  2.526  0.957
# 1      Random Forest  5.338  6.785  0.690
# 2  Gradient Boosting  3.825  5.545  0.793

# %%
best_mae_model = results_spi.loc[results_spi["MAE"].idxmin(), "Model"]
best_rmse_model = results_spi.loc[results_spi["RMSE"].idxmin(), "Model"]
best_r2_model = results_spi.loc[results_spi["R²"].idxmax(), "Model"]

print("Best MAE model:", best_mae_model)
print("Best RMSE model:", best_rmse_model)
print("Best R² model:", best_r2_model)
# Out:
# Best MAE model: Ridge
# Best RMSE model: Ridge
# Best R² model: Ridge

# %% [markdown]
# # **ML2 for SPI** (train score)

# %%
train_score = R_model.score(X2_train, y2_train)

print("Train:", train_score)
# Out:
# Train: 0.9826931326913335

# %% [markdown]
# #  **ML2 for SPI** (cross validation score for the ML of SPI)

# %%
from sklearn.model_selection import cross_val_score

ridge_cv = cross_val_score(
    R_model,
    X2,
    y2,
    cv=5,
    scoring="r2"
)

print("Ridge CV R²:", ridge_cv)
print("Mean CV R²:", ridge_cv.mean())
print("Std CV R²:", ridge_cv.std())
# Out:
# Ridge CV R²: [0.94477668 0.96462851 0.96923528 0.96161481 0.94215421]
# Mean CV R²: 0.9564818946619486
# Std CV R²: 0.010933046282085955

# %% [markdown]
# #  **ML2 for SPI** (permutation importance for the best test)

# %%
from sklearn.inspection import permutation_importance

Ridge_perm = permutation_importance(
    R_model,
    X2_test,
    y2_test,
    n_repeats=30,
    random_state=42,
    scoring="r2"
)

# %%
feature_names = X2_test.columns

Ridge_importance = pd.DataFrame({
    "Feature": feature_names,
    "Importance": Ridge_perm.importances_mean
})

Ridge_importance = Ridge_importance.sort_values(
    "Importance",
    ascending=False
)

top_features = Ridge_importance.head(10)

plt.figure(figsize=(10, 6))

plt.barh(
    top_features["Feature"],
    top_features["Importance"]
)

plt.xlabel("Permutation Importance")
plt.ylabel("Feature")
plt.title("Top 10 Predictors of SPI — Ridge")
plt.gca().invert_yaxis()

plt.show()
