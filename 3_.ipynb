# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"D:\Projects\Data\Supply_Chain_dataset.csv")

df['shipping_date_(DateOrders)'] = pd.to_datetime(df['shipping_date_(DateOrders)'])
df = df.drop(columns="Order_Zipcode")
df = df.drop(columns="Product_Description")
df = df.drop(columns="Product_Image")
df = df.drop(columns="Customer_Email")
df = df.drop(columns="Product_Status")
df = df.drop(columns="Customer_Password")
df= df.drop(columns="Longitude")
df = df.drop(columns="Latitude")
df = df.dropna()
df.drop('Order_Profit_Per_Order', axis=1, inplace=True)

duplicate_cols = []
for i in range(len(df.columns)):
    for j in range(i + 1, len(df.columns)):
        if df.iloc[:, i].equals(df.iloc[:, j]):
            duplicate_cols.append(df.columns[j])

df = df.drop(columns=duplicate_cols)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 180508 entries, 0 to 180518
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180508 non-null  str
#  1   Days_for_shipping_(real)       180508 non-null  int64
#  2   Days_for_shipment_(scheduled)  180508 non-null  int64
#  3   Benefit_per_order              180508 non-null  float64
#  4   Sales_per_customer             180508 non-null  float64
#  5   Delivery_Status                180508 non-null  str
#  6   Late_delivery_risk             180508 non-null  int64
#  7   Category_Id                    180508 non-null  int64
#  8   Category_Name                  180508 non-null  str
#  9   Customer_City                  180508 non-null  str
#  10  Customer_Country               180508 non-null  str
#  11  Customer_Fname                 180508 non-null  str
#  12  Customer_Id                    180508 non-null  int64
#  13  Customer_Lname                 180508 non-null  str
#  14  Customer_Segment               180508 non-null  str
#  15  Customer_State                 180508 non-null  str
#  16  Customer_Street                180508 non-null  str
#  17  Customer_Zipcode               180508 non-null  float64
#  18  Department_Id                  180508 non-null  int64
#  19  Department_Name                180508 non-null  str
#  20  Market                         180508 non-null  str
#  21  Order_City                     180508 non-null  str
#  22  Order_Country                  180508 non-null  str
#  23  order_date_(DateOrders)        180508 non-null  str
#  24  Order_Id                       180508 non-null  int64
#  25  Order_Item_Cardprod_Id         180508 non-null  int64
#  26  Order_Item_Discount            180508 non-null  float64
#  27  Order_Item_Discount_Rate       180508 non-null  float64
#  28  Order_Item_Id                  180508 non-null  int64
#  29  Order_Item_Product_Price       180508 non-null  int64
#  30  Order_Item_Profit_Ratio        180508 non-null  float64
#  31  Order_Item_Quantity            180508 non-null  int64
#  32  Sales                          180508 non-null  float64
#  33  Order_Region                   180508 non-null  str
#  34  Order_State                    180508 non-null  str
#  35  Order_Status                   180508 non-null  str
#  36  Product_Name                   180508 non-null  str
#  37  Product_Price                  180508 non-null  float64
#  38  shipping_date_(DateOrders)     180508 non-null  datetime64[us]
#  39  Shipping_Mode                  180508 non-null  str
# dtypes: datetime64[us](1), float64(8), int64(11), str(20)
# memory usage: 56.5 MB

# %%
df_Com_Stat= df[df['Order_Status'] == 'COMPLETE']

# %%
df_Com_Stat.to_csv(r"D:\Projects\Data\Supply_Chain_dataset_cleaned.csv")
