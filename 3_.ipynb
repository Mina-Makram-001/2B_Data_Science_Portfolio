# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"E:\2_projects\7_2B_Project\Data\Supply_Chain_dataset.csv")

df['shipping_date_(DateOrders)'] = pd.to_datetime(df['shipping_date_(DateOrders)'])
df = df.drop(columns="Order_Zipcode")
df = df.drop(columns="Product_Description")
df = df.dropna()
df.drop('Order_Profit_Per_Order', axis=1, inplace=True)

duplicate_cols = []
for i in range(len(df.columns)):
    for j in range(i + 1, len(df.columns)):
        if df.iloc[:, i].equals(df.iloc[:, j]):
            duplicate_cols.append(df.columns[j])

df = df.drop(columns=duplicate_cols)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 180508 entries, 0 to 180518
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180508 non-null  object
#  1   Days_for_shipping_(real)       180508 non-null  int64
#  2   Days_for_shipment_(scheduled)  180508 non-null  int64
#  3   Benefit_per_order              180508 non-null  float64
#  4   Sales_per_customer             180508 non-null  float64
#  5   Delivery_Status                180508 non-null  object
#  6   Late_delivery_risk             180508 non-null  int64
#  7   Category_Id                    180508 non-null  int64
#  8   Category_Name                  180508 non-null  object
#  9   Customer_City                  180508 non-null  object
#  10  Customer_Country               180508 non-null  object
#  11  Customer_Email                 180508 non-null  object
#  12  Customer_Fname                 180508 non-null  object
#  13  Customer_Id                    180508 non-null  int64
#  14  Customer_Lname                 180508 non-null  object
#  15  Customer_Segment               180508 non-null  object
#  16  Customer_State                 180508 non-null  object
#  17  Customer_Street                180508 non-null  object
#  18  Customer_Zipcode               180508 non-null  float64
#  19  Department_Id                  180508 non-null  int64
#  20  Department_Name                180508 non-null  object
#  21  Latitude                       180508 non-null  float64
#  22  Longitude                      180508 non-null  float64
#  23  Market                         180508 non-null  object
#  24  Order_City                     180508 non-null  object
#  25  Order_Country                  180508 non-null  object
#  26  order_date_(DateOrders)        180508 non-null  object
#  27  Order_Id                       180508 non-null  int64
#  28  Order_Item_Cardprod_Id         180508 non-null  int64
#  29  Order_Item_Discount            180508 non-null  float64
#  30  Order_Item_Discount_Rate       180508 non-null  float64
#  31  Order_Item_Id                  180508 non-null  int64
#  32  Order_Item_Product_Price       180508 non-null  int64
#  33  Order_Item_Profit_Ratio        180508 non-null  float64
#  34  Order_Item_Quantity            180508 non-null  int64
#  35  Sales                          180508 non-null  float64
#  36  Order_Region                   180508 non-null  object
#  37  Order_State                    180508 non-null  object
#  38  Order_Status                   180508 non-null  object
#  39  Product_Image                  180508 non-null  object
#  40  Product_Name                   180508 non-null  object
#  41  Product_Price                  180508 non-null  float64
#  42  Product_Status                 180508 non-null  int64
#  43  shipping_date_(DateOrders)     180508 non-null  datetime64[ns]
#  44  Shipping_Mode                  180508 non-null  object
# dtypes: datetime64[ns](1), float64(10), int64(12), object(22)
# memory usage: 63.3+ MB
