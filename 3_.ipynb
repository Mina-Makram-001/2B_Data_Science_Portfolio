# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"D:\Projects\Data\Supply_Chain_dataset.csv")

df['shipping_date_(DateOrders)'] = pd.to_datetime(df['shipping_date_(DateOrders)'])
df = df.drop(columns="Order_Zipcode")
df = df.drop(columns="Product_Description")
df = df.dropna()
df.drop('Order_Profit_Per_Order', axis=1, inplace=True)
df.drop('Order_Item_Discount', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 180508 entries, 0 to 180518
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180508 non-null  str
#  1   Days_for_shipping_(real)       180508 non-null  int64
#  2   Days_for_shipment_(scheduled)  180508 non-null  int64
#  3   Benefit_per_order              180508 non-null  float64
#  4   Sales_per_customer             180508 non-null  float64
#  5   Delivery_Status                180508 non-null  str
#  6   Late_delivery_risk             180508 non-null  int64
#  7   Category_Id                    180508 non-null  int64
#  8   Category_Name                  180508 non-null  str
#  9   Customer_City                  180508 non-null  str
#  10  Customer_Country               180508 non-null  str
#  11  Customer_Email                 180508 non-null  str
#  12  Customer_Fname                 180508 non-null  str
#  13  Customer_Id                    180508 non-null  int64
#  14  Customer_Lname                 180508 non-null  str
#  15  Customer_Password              180508 non-null  str
#  16  Customer_Segment               180508 non-null  str
#  17  Customer_State                 180508 non-null  str
#  18  Customer_Street                180508 non-null  str
#  19  Customer_Zipcode               180508 non-null  float64
#  20  Department_Id                  180508 non-null  int64
#  21  Department_Name                180508 non-null  str
#  22  Latitude                       180508 non-null  float64
#  23  Longitude                      180508 non-null  float64
#  24  Market                         180508 non-null  str
#  25  Order_City                     180508 non-null  str
#  26  Order_Country                  180508 non-null  str
#  27  Order_Customer_Id              180508 non-null  int64
#  28  order_date_(DateOrders)        180508 non-null  str
#  29  Order_Id                       180508 non-null  int64
#  30  Order_Item_Cardprod_Id         180508 non-null  int64
#  31  Order_Item_Discount_Rate       180508 non-null  float64
#  32  Order_Item_Id                  180508 non-null  int64
#  33  Order_Item_Product_Price       180508 non-null  int64
#  34  Order_Item_Profit_Ratio        180508 non-null  float64
#  35  Order_Item_Quantity            180508 non-null  int64
#  36  Sales                          180508 non-null  float64
#  37  Order_Item_Total               180508 non-null  float64
#  38  Order_Region                   180508 non-null  str
#  39  Order_State                    180508 non-null  str
#  40  Order_Status                   180508 non-null  str
#  41  Product_Card_Id                180508 non-null  int64
#  42  Product_Category_Id            180508 non-null  int64
#  43  Product_Image                  180508 non-null  str
#  44  Product_Name                   180508 non-null  str
#  45  Product_Price                  180508 non-null  float64
#  46  Product_Status                 180508 non-null  int64
#  47  shipping_date_(DateOrders)     180508 non-null  datetime64[us]
#  48  Shipping_Mode                  180508 non-null  str
# dtypes: datetime64[us](1), float64(10), int64(15), str(23)
# memory usage: 68.9 MB
